# %% [markdown]
# ## 1. VHM Dataset

# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('../Datasets/1-VHM Historical Data.csv')
df_reversed = df.iloc[::-1].reset_index(drop=True)
df['Date'] = pd.to_datetime(df_reversed['Date'])
df1 = df_reversed['Price']
df1 = df1.str.replace(',', '').astype(float)

# %%
df1
# Out:
# 0       68421.0
# 1       70075.0
# 2       68421.0
# 3       69022.0
# 4       69173.0
#          ...
# 1247    43350.0
# 1248    44200.0
# 1249    44400.0
# 1250    43400.0
# 1251    43950.0
# Name: Price, Length: 1252, dtype: float64

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy

# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Define MLP Model
model = Sequential()
model.add(Dense(50, input_dim=100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 8. Fit mô hình với dữ liệu train
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 2s 31ms/step - loss: 0.1148 - val_loss: 0.0163
# Epoch 2/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0153 - val_loss: 0.0114
# Epoch 3/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0082 - val_loss: 0.0066
# Epoch 4/100
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0063 - val_loss: 0.0050
# Epoch 5/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 6/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0042
# Epoch 7/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 0.0042
# Epoch 8/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 0.0040
# Epoch 9/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0034 - val_loss: 0.0037
# Epoch 10/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 11/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 0.0042
# Epoch 12/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0030 - val_loss: 0.0043
# Epoch 13/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0041
# Epoch 14/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0040
# Epoch 15/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 16/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0033
# Epoch 17/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0038
# Epoch 18/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 19/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0033
# Epoch 20/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0030 - val_loss: 0.0045
# Epoch 21/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 0.0032
# Epoch 22/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 23/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 0.0029
# Epoch 24/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0032 - val_loss: 0.0045
# Epoch 25/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 26/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0026 - val_loss: 0.0038
# Epoch 27/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 0.0035
# Epoch 28/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 29/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0033
# Epoch 30/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0031
# Epoch 31/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0035
# Epoch 32/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0028
# Epoch 33/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 34/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0028
# Epoch 35/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0031
# Epoch 36/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 37/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0032
# Epoch 38/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0031
# Epoch 39/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 40/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 41/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 42/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 43/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 44/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 45/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0029
# Epoch 46/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0026
# Epoch 47/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 48/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 49/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 50/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 51/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0026
# Epoch 52/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0029
# Epoch 53/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0028
# Epoch 54/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 55/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 56/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 57/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 58/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 59/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 60/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 61/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 62/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 63/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 64/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 65/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 66/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 67/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0025
# Epoch 68/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0032
# Epoch 69/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 70/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 71/100
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 72/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 73/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 74/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 75/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 76/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 77/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 78/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0025
# Epoch 79/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0025
# Epoch 80/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 81/100
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 82/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 83/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 84/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 85/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 86/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 87/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 88/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 89/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 90/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 91/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 92/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 93/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 94/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 95/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0027
# Epoch 96/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 97/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 98/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 99/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 100/100
# 13/13 [==============================] - 0s 7ms/step - loss: 9.9561e-04 - val_loss: 0.0018

# %%
# 9. Dự báo dữ liệu test
train_predict = model.predict(X_train)
y_pred = model.predict(X_test)
# Out:
# 25/25 [==============================] - 0s 1ms/step
# 9/9 [==============================] - 0s 2ms/step

# %%
# 10. Chuẩn hóa dữ liệu y_pred
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# %%
# 11. Đánh giá độ chính xác thuật toán bằng RMSE và các độ đo khác
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
test_mape = mean_absolute_percentage_error(y_test, y_pred)
test_mae = mean_absolute_error(y_test, y_pred)

print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 49264.20502102081
# Testing MAPE: 6.694769091361467e+17
# Testing MAE: 48937.128639600574

# %%
# 12. Dự báo 30 ngày tiếp theo
x_input = test_data[-100:].reshape(1, -1)
temp_input = x_input[0].tolist()

from numpy import array

lst_output = []
n_steps = 100
i = 0
while i < 30:
    if len(temp_input) > 100:
        x_input = np.array(temp_input[-100:])
        x_input = x_input.reshape((1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = np.array(temp_input).reshape((1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i += 1

# %%
# 13. Vẽ hình
plt.figure(figsize=(14, 8))
dates = pd.to_datetime(df_reversed['Date'])

plt.plot(dates[:train_size], scaler.inverse_transform(train_data), label='Train')
plt.plot(dates[train_size:], scaler.inverse_transform(test_data), label='Test')
predicted_test_index_start = train_size + time_step
plt.plot(dates[predicted_test_index_start:predicted_test_index_start + len(y_pred)], y_pred, label='Predict')
future_dates = pd.date_range(start=dates.iloc[-1], periods=31, inclusive='right')
plt.plot(future_dates, scaler.inverse_transform(lst_output), label='30 Days Prediction')

plt.title('VHM Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Closed Price')
plt.legend()

plt.show()

# %% [markdown]
# ## 2. NVL Dataset

# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('../Datasets/2-NVL Historical Data.csv')
df_reversed = df.iloc[::-1].reset_index(drop=True)
df['Date'] = pd.to_datetime(df_reversed['Date'])
df1 = df_reversed['Price']
df1 = df1.str.replace(',', '').astype(float)

# %%
df1
# Out:
# 0       32933.0
# 1       33100.0
# 2       32711.0
# 3       31709.0
# 4       31932.0
#          ...
# 1247    16800.0
# 1248    17050.0
# 1249    17000.0
# 1250    17100.0
# 1251    17300.0
# Name: Price, Length: 1252, dtype: float64

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy

# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Define MLP Model
model = Sequential()
model.add(Dense(50, input_dim=100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 8. Fit mô hình với dữ liệu train
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 27ms/step - loss: 0.0253 - val_loss: 7.4670e-04
# Epoch 2/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0060 - val_loss: 9.7021e-04
# Epoch 3/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0040 - val_loss: 0.0012
# Epoch 4/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0017
# Epoch 5/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0027
# Epoch 6/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 7/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 8/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0047
# Epoch 9/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 10/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0012 - val_loss: 0.0054
# Epoch 11/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0052
# Epoch 12/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0054
# Epoch 13/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0056
# Epoch 14/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 0.0048
# Epoch 15/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0054
# Epoch 16/100
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6945e-04 - val_loss: 0.0052
# Epoch 17/100
# 13/13 [==============================] - 0s 5ms/step - loss: 9.4744e-04 - val_loss: 0.0054
# Epoch 18/100
# 13/13 [==============================] - 0s 5ms/step - loss: 8.9813e-04 - val_loss: 0.0052
# Epoch 19/100
# 13/13 [==============================] - 0s 6ms/step - loss: 8.7461e-04 - val_loss: 0.0055
# Epoch 20/100
# 13/13 [==============================] - 0s 6ms/step - loss: 9.3982e-04 - val_loss: 0.0050
# Epoch 21/100
# 13/13 [==============================] - 0s 5ms/step - loss: 8.4538e-04 - val_loss: 0.0050
# Epoch 22/100
# 13/13 [==============================] - 0s 6ms/step - loss: 8.8796e-04 - val_loss: 0.0048
# Epoch 23/100
# 13/13 [==============================] - 0s 6ms/step - loss: 7.9772e-04 - val_loss: 0.0048
# Epoch 24/100
# 13/13 [==============================] - 0s 6ms/step - loss: 7.8293e-04 - val_loss: 0.0049
# Epoch 25/100
# 13/13 [==============================] - 0s 5ms/step - loss: 7.8649e-04 - val_loss: 0.0048
# Epoch 26/100
# 13/13 [==============================] - 0s 5ms/step - loss: 7.7207e-04 - val_loss: 0.0047
# Epoch 27/100
# 13/13 [==============================] - 0s 4ms/step - loss: 7.3021e-04 - val_loss: 0.0051
# Epoch 28/100
# 13/13 [==============================] - 0s 5ms/step - loss: 7.2373e-04 - val_loss: 0.0056
# Epoch 29/100
# 13/13 [==============================] - 0s 5ms/step - loss: 9.6398e-04 - val_loss: 0.0046
# Epoch 30/100
# 13/13 [==============================] - 0s 6ms/step - loss: 8.1709e-04 - val_loss: 0.0045
# Epoch 31/100
# 13/13 [==============================] - 0s 4ms/step - loss: 7.1773e-04 - val_loss: 0.0047
# Epoch 32/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.8861e-04 - val_loss: 0.0054
# Epoch 33/100
# 13/13 [==============================] - 0s 4ms/step - loss: 7.2573e-04 - val_loss: 0.0048
# Epoch 34/100
# 13/13 [==============================] - 0s 4ms/step - loss: 6.7883e-04 - val_loss: 0.0048
# Epoch 35/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.6819e-04 - val_loss: 0.0051
# Epoch 36/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.4866e-04 - val_loss: 0.0049
# Epoch 37/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.2652e-04 - val_loss: 0.0051
# Epoch 38/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.2434e-04 - val_loss: 0.0051
# Epoch 39/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.1624e-04 - val_loss: 0.0048
# Epoch 40/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.2201e-04 - val_loss: 0.0055
# Epoch 41/100
# 13/13 [==============================] - 0s 5ms/step - loss: 7.4533e-04 - val_loss: 0.0046
# Epoch 42/100
# 13/13 [==============================] - 0s 5ms/step - loss: 7.6998e-04 - val_loss: 0.0051
# Epoch 43/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.0172e-04 - val_loss: 0.0049
# Epoch 44/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.3393e-04 - val_loss: 0.0056
# Epoch 45/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.3567e-04 - val_loss: 0.0049
# Epoch 46/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.3790e-04 - val_loss: 0.0052
# Epoch 47/100
# 13/13 [==============================] - 0s 4ms/step - loss: 6.3114e-04 - val_loss: 0.0051
# Epoch 48/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.0589e-04 - val_loss: 0.0056
# Epoch 49/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.7403e-04 - val_loss: 0.0054
# Epoch 50/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.4026e-04 - val_loss: 0.0059
# Epoch 51/100
# 13/13 [==============================] - 0s 8ms/step - loss: 8.0836e-04 - val_loss: 0.0052
# Epoch 52/100
# 13/13 [==============================] - 0s 5ms/step - loss: 7.1163e-04 - val_loss: 0.0051
# Epoch 53/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.6068e-04 - val_loss: 0.0053
# Epoch 54/100
# 13/13 [==============================] - 0s 5ms/step - loss: 5.9114e-04 - val_loss: 0.0053
# Epoch 55/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.8989e-04 - val_loss: 0.0052
# Epoch 56/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.8622e-04 - val_loss: 0.0053
# Epoch 57/100
# 13/13 [==============================] - 0s 5ms/step - loss: 7.2249e-04 - val_loss: 0.0054
# Epoch 58/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.7800e-04 - val_loss: 0.0055
# Epoch 59/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.8651e-04 - val_loss: 0.0052
# Epoch 60/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.2429e-04 - val_loss: 0.0058
# Epoch 61/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.1057e-04 - val_loss: 0.0059
# Epoch 62/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.6719e-04 - val_loss: 0.0052
# Epoch 63/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.4212e-04 - val_loss: 0.0055
# Epoch 64/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.6565e-04 - val_loss: 0.0061
# Epoch 65/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.3488e-04 - val_loss: 0.0056
# Epoch 66/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.4033e-04 - val_loss: 0.0059
# Epoch 67/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.4920e-04 - val_loss: 0.0063
# Epoch 68/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 0.0056
# Epoch 69/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.2835e-04 - val_loss: 0.0055
# Epoch 70/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.3097e-04 - val_loss: 0.0050
# Epoch 71/100
# 13/13 [==============================] - 0s 6ms/step - loss: 8.0669e-04 - val_loss: 0.0052
# Epoch 72/100
# 13/13 [==============================] - 0s 6ms/step - loss: 8.4489e-04 - val_loss: 0.0053
# Epoch 73/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.1568e-04 - val_loss: 0.0061
# Epoch 74/100
# 13/13 [==============================] - 0s 5ms/step - loss: 5.7991e-04 - val_loss: 0.0061
# Epoch 75/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.1570e-04 - val_loss: 0.0059
# Epoch 76/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.5364e-04 - val_loss: 0.0064
# Epoch 77/100
# 13/13 [==============================] - 0s 7ms/step - loss: 7.5722e-04 - val_loss: 0.0056
# Epoch 78/100
# 13/13 [==============================] - 0s 6ms/step - loss: 8.6814e-04 - val_loss: 0.0063
# Epoch 79/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.4164e-04 - val_loss: 0.0051
# Epoch 80/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.0520e-04 - val_loss: 0.0049
# Epoch 81/100
# 13/13 [==============================] - 0s 5ms/step - loss: 5.5508e-04 - val_loss: 0.0053
# Epoch 82/100
# 13/13 [==============================] - 0s 5ms/step - loss: 5.1381e-04 - val_loss: 0.0057
# Epoch 83/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.1254e-04 - val_loss: 0.0057
# Epoch 84/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.0296e-04 - val_loss: 0.0062
# Epoch 85/100
# 13/13 [==============================] - 0s 6ms/step - loss: 7.2651e-04 - val_loss: 0.0054
# Epoch 86/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.9192e-04 - val_loss: 0.0058
# Epoch 87/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.5417e-04 - val_loss: 0.0055
# Epoch 88/100
# 13/13 [==============================] - 0s 6ms/step - loss: 4.9898e-04 - val_loss: 0.0056
# Epoch 89/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.6158e-04 - val_loss: 0.0050
# Epoch 90/100
# 13/13 [==============================] - 0s 7ms/step - loss: 4.9769e-04 - val_loss: 0.0054
# Epoch 91/100
# 13/13 [==============================] - 0s 5ms/step - loss: 4.9389e-04 - val_loss: 0.0056
# Epoch 92/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.0622e-04 - val_loss: 0.0054
# Epoch 93/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.0614e-04 - val_loss: 0.0052
# Epoch 94/100
# 13/13 [==============================] - 0s 6ms/step - loss: 4.6028e-04 - val_loss: 0.0056
# Epoch 95/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.0568e-04 - val_loss: 0.0056
# Epoch 96/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.6118e-04 - val_loss: 0.0059
# Epoch 97/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.1303e-04 - val_loss: 0.0053
# Epoch 98/100
# 13/13 [==============================] - 0s 6ms/step - loss: 4.5558e-04 - val_loss: 0.0051
# Epoch 99/100
# 13/13 [==============================] - 0s 6ms/step - loss: 4.4797e-04 - val_loss: 0.0052
# Epoch 100/100
# 13/13 [==============================] - 0s 6ms/step - loss: 4.3618e-04 - val_loss: 0.0053

# %%
# 9. Dự báo dữ liệu test
train_predict = model.predict(X_train)
y_pred = model.predict(X_test)
# Out:
# 25/25 [==============================] - 0s 1ms/step
# 9/9 [==============================] - 0s 2ms/step

# %%
# 10. Chuẩn hóa dữ liệu y_pred
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# %%
# 11. Đánh giá độ chính xác thuật toán bằng RMSE và các độ đo khác
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
test_mape = mean_absolute_percentage_error(y_test, y_pred)
test_mae = mean_absolute_error(y_test, y_pred)

print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 14699.949712798552
# Testing MAPE: 6.35188467102453e+16
# Testing MAE: 13793.301560335314

# %%
# 12. Dự báo 30 ngày tiếp theo
x_input = test_data[-100:].reshape(1, -1)
temp_input = x_input[0].tolist()

from numpy import array

lst_output = []
n_steps = 100
i = 0
while i < 30:
    if len(temp_input) > 100:
        x_input = np.array(temp_input[-100:])
        x_input = x_input.reshape((1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = np.array(temp_input).reshape((1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i += 1

# %%
# 13. Vẽ hình
plt.figure(figsize=(14, 8))
dates = pd.to_datetime(df_reversed['Date'])

plt.plot(dates[:train_size], scaler.inverse_transform(train_data), label='Train')
plt.plot(dates[train_size:], scaler.inverse_transform(test_data), label='Test')
predicted_test_index_start = train_size + time_step
plt.plot(dates[predicted_test_index_start:predicted_test_index_start + len(y_pred)], y_pred, label='Predict')
future_dates = pd.date_range(start=dates.iloc[-1], periods=31, inclusive='right')
plt.plot(future_dates, scaler.inverse_transform(lst_output), label='30 Days Prediction')

plt.title('NVL Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Closed Price')
plt.legend()

plt.show()

# %% [markdown]
# ## 3. NLG Dataset

# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('../Datasets/3-NLG Historical Data.csv')
df_reversed = df.iloc[::-1].reset_index(drop=True)
df['Date'] = pd.to_datetime(df_reversed['Date'])
df1 = df_reversed['Price']
df1 = df1.str.replace(',', '').astype(float)

# %%
df1
# Out:
# 0       18706.8
# 1       19127.2
# 2       18917.0
# 3       18846.9
# 4       18706.8
#          ...
# 1247    37400.0
# 1248    38500.0
# 1249    38200.0
# 1250    39600.0
# 1251    39900.0
# Name: Price, Length: 1252, dtype: float64

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.7 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy

# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Define MLP Model
model = Sequential()
model.add(Dense(50, input_dim=100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 8. Fit mô hình với dữ liệu train
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 18ms/step - loss: 0.0851 - val_loss: 0.0156
# Epoch 2/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0097 - val_loss: 0.0041
# Epoch 3/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - val_loss: 0.0031
# Epoch 4/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0037 - val_loss: 0.0025
# Epoch 5/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0029 - val_loss: 0.0021
# Epoch 6/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0021
# Epoch 7/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0025 - val_loss: 0.0020
# Epoch 8/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 9/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 10/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 11/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 12/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 13/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 14/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 15/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 16/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 17/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 18/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 19/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 20/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 21/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 22/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 23/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 24/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 25/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 26/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 27/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 28/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 29/100
# 13/13 [==============================] - 0s 5ms/step - loss: 9.8957e-04 - val_loss: 0.0019
# Epoch 30/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 31/100
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 9.8776e-04
# Epoch 32/100
# 13/13 [==============================] - 0s 6ms/step - loss: 8.6955e-04 - val_loss: 0.0011
# Epoch 33/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 34/100
# 13/13 [==============================] - 0s 6ms/step - loss: 8.2577e-04 - val_loss: 0.0010
# Epoch 35/100
# 13/13 [==============================] - 0s 7ms/step - loss: 7.7994e-04 - val_loss: 9.2697e-04
# Epoch 36/100
# 13/13 [==============================] - 0s 7ms/step - loss: 7.7918e-04 - val_loss: 0.0011
# Epoch 37/100
# 13/13 [==============================] - 0s 5ms/step - loss: 8.9010e-04 - val_loss: 9.0113e-04
# Epoch 38/100
# 13/13 [==============================] - 0s 5ms/step - loss: 7.2756e-04 - val_loss: 9.8735e-04
# Epoch 39/100
# 13/13 [==============================] - 0s 6ms/step - loss: 7.2547e-04 - val_loss: 9.3042e-04
# Epoch 40/100
# 13/13 [==============================] - 0s 7ms/step - loss: 6.7299e-04 - val_loss: 0.0012
# Epoch 41/100
# 13/13 [==============================] - 0s 5ms/step - loss: 7.3591e-04 - val_loss: 9.8161e-04
# Epoch 42/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.8672e-04 - val_loss: 8.6047e-04
# Epoch 43/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.4404e-04 - val_loss: 9.9625e-04
# Epoch 44/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.6984e-04 - val_loss: 0.0010
# Epoch 45/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.5509e-04 - val_loss: 9.0007e-04
# Epoch 46/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.0964e-04 - val_loss: 0.0012
# Epoch 47/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.2416e-04 - val_loss: 9.0708e-04
# Epoch 48/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.6858e-04 - val_loss: 8.8372e-04
# Epoch 49/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.9659e-04 - val_loss: 9.8351e-04
# Epoch 50/100
# 13/13 [==============================] - 0s 5ms/step - loss: 7.6661e-04 - val_loss: 9.2486e-04
# Epoch 51/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 52/100
# 13/13 [==============================] - 0s 6ms/step - loss: 7.4339e-04 - val_loss: 8.6756e-04
# Epoch 53/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.7634e-04 - val_loss: 8.5820e-04
# Epoch 54/100
# 13/13 [==============================] - 0s 6ms/step - loss: 7.5659e-04 - val_loss: 0.0010
# Epoch 55/100
# 13/13 [==============================] - 0s 5ms/step - loss: 5.9984e-04 - val_loss: 8.6476e-04
# Epoch 56/100
# 13/13 [==============================] - 0s 5ms/step - loss: 5.9940e-04 - val_loss: 8.7828e-04
# Epoch 57/100
# 13/13 [==============================] - 0s 7ms/step - loss: 5.9293e-04 - val_loss: 8.6484e-04
# Epoch 58/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.8563e-04 - val_loss: 0.0011
# Epoch 59/100
# 13/13 [==============================] - 0s 5ms/step - loss: 5.9368e-04 - val_loss: 8.3442e-04
# Epoch 60/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.3946e-04 - val_loss: 8.9791e-04
# Epoch 61/100
# 13/13 [==============================] - 0s 7ms/step - loss: 6.4252e-04 - val_loss: 8.5071e-04
# Epoch 62/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.1661e-04 - val_loss: 0.0015
# Epoch 63/100
# 13/13 [==============================] - 0s 5ms/step - loss: 8.8608e-04 - val_loss: 0.0013
# Epoch 64/100
# 13/13 [==============================] - 0s 6ms/step - loss: 7.3056e-04 - val_loss: 8.9839e-04
# Epoch 65/100
# 13/13 [==============================] - 0s 5ms/step - loss: 5.7955e-04 - val_loss: 0.0013
# Epoch 66/100
# 13/13 [==============================] - 0s 5ms/step - loss: 7.3235e-04 - val_loss: 0.0011
# Epoch 67/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.8543e-04 - val_loss: 9.0205e-04
# Epoch 68/100
# 13/13 [==============================] - 0s 5ms/step - loss: 5.8813e-04 - val_loss: 0.0011
# Epoch 69/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.3739e-04 - val_loss: 0.0010
# Epoch 70/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.2915e-04 - val_loss: 8.4651e-04
# Epoch 71/100
# 13/13 [==============================] - 0s 5ms/step - loss: 4.9677e-04 - val_loss: 8.3537e-04
# Epoch 72/100
# 13/13 [==============================] - 0s 5ms/step - loss: 5.1437e-04 - val_loss: 8.8700e-04
# Epoch 73/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.1248e-04 - val_loss: 0.0010
# Epoch 74/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.4810e-04 - val_loss: 0.0010
# Epoch 75/100
# 13/13 [==============================] - 0s 8ms/step - loss: 7.8831e-04 - val_loss: 0.0015
# Epoch 76/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 77/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 78/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.9889e-04 - val_loss: 0.0012
# Epoch 79/100
# 13/13 [==============================] - 0s 6ms/step - loss: 6.6628e-04 - val_loss: 9.1076e-04
# Epoch 80/100
# 13/13 [==============================] - 0s 6ms/step - loss: 7.8682e-04 - val_loss: 0.0016
# Epoch 81/100
# 13/13 [==============================] - 0s 6ms/step - loss: 8.0079e-04 - val_loss: 9.7259e-04
# Epoch 82/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.6180e-04 - val_loss: 0.0013
# Epoch 83/100
# 13/13 [==============================] - 0s 6ms/step - loss: 7.0782e-04 - val_loss: 8.3281e-04
# Epoch 84/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.1842e-04 - val_loss: 8.4067e-04
# Epoch 85/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.0179e-04 - val_loss: 8.1349e-04
# Epoch 86/100
# 13/13 [==============================] - 0s 5ms/step - loss: 4.7723e-04 - val_loss: 8.2418e-04
# Epoch 87/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.5272e-04 - val_loss: 7.9233e-04
# Epoch 88/100
# 13/13 [==============================] - 0s 5ms/step - loss: 4.7964e-04 - val_loss: 8.5060e-04
# Epoch 89/100
# 13/13 [==============================] - 0s 5ms/step - loss: 4.7195e-04 - val_loss: 8.3678e-04
# Epoch 90/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.7785e-04 - val_loss: 0.0017
# Epoch 91/100
# 13/13 [==============================] - 0s 6ms/step - loss: 9.4010e-04 - val_loss: 9.3433e-04
# Epoch 92/100
# 13/13 [==============================] - 0s 6ms/step - loss: 5.6913e-04 - val_loss: 0.0018
# Epoch 93/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 8.6016e-04
# Epoch 94/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 0.0015
# Epoch 95/100
# 13/13 [==============================] - 0s 5ms/step - loss: 8.9667e-04 - val_loss: 0.0014
# Epoch 96/100
# 13/13 [==============================] - 0s 5ms/step - loss: 6.4004e-04 - val_loss: 8.0541e-04
# Epoch 97/100
# 13/13 [==============================] - 0s 5ms/step - loss: 5.1364e-04 - val_loss: 9.2652e-04
# Epoch 98/100
# 13/13 [==============================] - 0s 4ms/step - loss: 5.7518e-04 - val_loss: 8.2279e-04
# Epoch 99/100
# 13/13 [==============================] - 0s 4ms/step - loss: 5.5441e-04 - val_loss: 8.0280e-04
# Epoch 100/100
# 13/13 [==============================] - 0s 4ms/step - loss: 4.6190e-04 - val_loss: 8.6936e-04

# %%
# 9. Dự báo dữ liệu test
train_predict = model.predict(X_train)
y_pred = model.predict(X_test)
# Out:
# 25/25 [==============================] - 0s 1ms/step
# 9/9 [==============================] - 0s 2ms/step

# %%
# 10. Chuẩn hóa dữ liệu y_pred
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# %%
# 11. Đánh giá độ chính xác thuật toán bằng RMSE và các độ đo khác
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
test_mape = mean_absolute_percentage_error(y_test, y_pred)
test_mae = mean_absolute_error(y_test, y_pred)

print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 34497.82181254914
# Testing MAPE: 89665.10636947476
# Testing MAE: 34213.497641612455

# %%
# 12. Dự báo 30 ngày tiếp theo
x_input = test_data[-100:].reshape(1, -1)
temp_input = x_input[0].tolist()

from numpy import array

lst_output = []
n_steps = 100
i = 0
while i < 30:
    if len(temp_input) > 100:
        x_input = np.array(temp_input[-100:])
        x_input = x_input.reshape((1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = np.array(temp_input).reshape((1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i += 1

# %%
# 13. Vẽ hình
plt.figure(figsize=(14, 8))
dates = pd.to_datetime(df_reversed['Date'])

plt.plot(dates[:train_size], scaler.inverse_transform(train_data), label='Train')
plt.plot(dates[train_size:], scaler.inverse_transform(test_data), label='Test')
predicted_test_index_start = train_size + time_step
plt.plot(dates[predicted_test_index_start:predicted_test_index_start + len(y_pred)], y_pred, label='Predict')
future_dates = pd.date_range(start=dates.iloc[-1], periods=31, inclusive='right')
plt.plot(future_dates, scaler.inverse_transform(lst_output), label='30 Days Prediction')

plt.title('NLG Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Closed Price')
plt.legend()

plt.show()
