# %% [markdown]
# ## 1. VHM Dataset

# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('../Datasets/1-VHM Historical Data.csv')
df_reversed = df.iloc[::-1].reset_index(drop=True)
df['Date'] = pd.to_datetime(df_reversed['Date'])
df1 = df_reversed['Price']
df1 = df1.str.replace(',', '').astype(float)

# %%
df1
# Out:
# 0       68421.0
# 1       70075.0
# 2       68421.0
# 3       69022.0
# 4       69173.0
#          ...
# 1247    43350.0
# 1248    44200.0
# 1249    44400.0
# 1250    43400.0
# 1251    43950.0
# Name: Price, Length: 1252, dtype: float64

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.8 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy

# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Define MLP Model
model = Sequential()
model.add(Dense(50, input_dim=100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 8. Fit mô hình với dữ liệu train
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 22ms/step - loss: 0.0627 - val_loss: 0.0087
# Epoch 2/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0075 - val_loss: 0.0050
# Epoch 3/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0052 - val_loss: 0.0036
# Epoch 4/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0044 - val_loss: 0.0041
# Epoch 5/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0041 - val_loss: 0.0034
# Epoch 6/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 7/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0039 - val_loss: 0.0045
# Epoch 8/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0041 - val_loss: 0.0030
# Epoch 9/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 10/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0031 - val_loss: 0.0033
# Epoch 11/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.0030 - val_loss: 0.0028
# Epoch 12/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 13/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 14/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 15/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 16/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0045
# Epoch 17/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 18/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0029 - val_loss: 0.0025
# Epoch 19/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 20/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 21/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0030
# Epoch 22/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0024 - val_loss: 0.0033
# Epoch 23/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 24/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0026 - val_loss: 0.0020
# Epoch 25/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0019
# Epoch 26/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 27/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 28/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0017
# Epoch 29/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 0.0016
# Epoch 30/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0023 - val_loss: 0.0031
# Epoch 31/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 32/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 33/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0019 - val_loss: 0.0025
# Epoch 34/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 35/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0024
# Epoch 36/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 37/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 38/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 39/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 40/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 41/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 42/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 43/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 44/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 45/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 46/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0022 - val_loss: 0.0016
# Epoch 47/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0030
# Epoch 48/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0027
# Epoch 49/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 50/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 51/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0022
# Epoch 52/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 53/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 54/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 55/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 56/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 57/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 58/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 59/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 60/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 61/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 0.0022
# Epoch 62/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 63/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 64/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 65/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 66/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 67/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 68/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0018
# Epoch 69/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 70/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 71/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 72/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 73/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 74/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 75/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 76/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 77/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 78/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 79/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 80/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 81/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 82/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 83/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 84/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 85/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 86/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 0.0023
# Epoch 87/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 88/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 89/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0022
# Epoch 90/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 91/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 92/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 93/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0019
# Epoch 94/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 95/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 96/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 97/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0014
# Epoch 98/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0020
# Epoch 99/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 100/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0017

# %%
# 9. Dự báo dữ liệu test
train_predict = model.predict(X_train)
y_pred = model.predict(X_test)
# Out:
# 29/29 [==============================] - 0s 2ms/step
# 5/5 [==============================] - 0s 3ms/step

# %%
# 10. Chuẩn hóa dữ liệu y_pred
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# %%
# 11. Đánh giá độ chính xác thuật toán bằng RMSE và các độ đo khác
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
test_mape = mean_absolute_percentage_error(y_test, y_pred)
test_mae = mean_absolute_error(y_test, y_pred)

print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 47509.52100031129
# Testing MAPE: 1.2411681319309788e+18
# Testing MAE: 46970.50028347457

# %%
# 12. Dự báo 30 ngày tiếp theo
x_input = test_data[-100:].reshape(1, -1)
temp_input = x_input[0].tolist()

from numpy import array

lst_output = []
n_steps = 100
i = 0
while i < 30:
    if len(temp_input) > 100:
        x_input = np.array(temp_input[-100:])
        x_input = x_input.reshape((1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = np.array(temp_input).reshape((1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i += 1

# %%
# 13. Vẽ hình
plt.figure(figsize=(14, 8))
dates = pd.to_datetime(df_reversed['Date'])

plt.plot(dates[:train_size], scaler.inverse_transform(train_data), label='Train')
plt.plot(dates[train_size:], scaler.inverse_transform(test_data), label='Test')
predicted_test_index_start = train_size + time_step
plt.plot(dates[predicted_test_index_start:predicted_test_index_start + len(y_pred)], y_pred, label='Predict')
future_dates = pd.date_range(start=dates.iloc[-1], periods=31, inclusive='right')
plt.plot(future_dates, scaler.inverse_transform(lst_output), label='30 Days Prediction')

plt.title('VHM Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Closed Price')
plt.legend()

plt.show()

# %% [markdown]
# ## 2. NVL Dataset

# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('../Datasets/2-NVL Historical Data.csv')
df_reversed = df.iloc[::-1].reset_index(drop=True)
df['Date'] = pd.to_datetime(df_reversed['Date'])
df1 = df_reversed['Price']
df1 = df1.str.replace(',', '').astype(float)

# %%
df1
# Out:
# 0       32933.0
# 1       33100.0
# 2       32711.0
# 3       31709.0
# 4       31932.0
#          ...
# 1247    16800.0
# 1248    17050.0
# 1249    17000.0
# 1250    17100.0
# 1251    17300.0
# Name: Price, Length: 1252, dtype: float64

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.8 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy

# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Define MLP Model
model = Sequential()
model.add(Dense(50, input_dim=100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 8. Fit mô hình với dữ liệu train
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 24ms/step - loss: 0.1396 - val_loss: 7.3153e-04
# Epoch 2/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0123 - val_loss: 5.4948e-04
# Epoch 3/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0075 - val_loss: 5.3810e-04
# Epoch 4/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.0035 - val_loss: 9.1743e-04
# Epoch 5/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 7.4415e-04
# Epoch 6/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 5.8272e-04
# Epoch 7/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 5.4230e-04
# Epoch 8/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 4.8296e-04
# Epoch 9/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 3.6315e-04
# Epoch 10/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 3.6054e-04
# Epoch 11/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 3.2017e-04
# Epoch 12/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 2.9834e-04
# Epoch 13/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 2.7949e-04
# Epoch 14/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 2.2361e-04
# Epoch 15/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 2.4268e-04
# Epoch 16/100
# 15/15 [==============================] - 0s 6ms/step - loss: 9.3269e-04 - val_loss: 1.8029e-04
# Epoch 17/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 2.4157e-04
# Epoch 18/100
# 15/15 [==============================] - 0s 5ms/step - loss: 9.0783e-04 - val_loss: 1.8920e-04
# Epoch 19/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 1.9696e-04
# Epoch 20/100
# 15/15 [==============================] - 0s 4ms/step - loss: 8.4929e-04 - val_loss: 1.7144e-04
# Epoch 21/100
# 15/15 [==============================] - 0s 5ms/step - loss: 7.9476e-04 - val_loss: 1.6723e-04
# Epoch 22/100
# 15/15 [==============================] - 0s 6ms/step - loss: 8.5678e-04 - val_loss: 1.6788e-04
# Epoch 23/100
# 15/15 [==============================] - 0s 5ms/step - loss: 7.9716e-04 - val_loss: 1.7391e-04
# Epoch 24/100
# 15/15 [==============================] - 0s 6ms/step - loss: 7.6434e-04 - val_loss: 1.6461e-04
# Epoch 25/100
# 15/15 [==============================] - 0s 5ms/step - loss: 7.3745e-04 - val_loss: 1.6363e-04
# Epoch 26/100
# 15/15 [==============================] - 0s 4ms/step - loss: 7.6890e-04 - val_loss: 1.5821e-04
# Epoch 27/100
# 15/15 [==============================] - 0s 6ms/step - loss: 7.9373e-04 - val_loss: 1.6609e-04
# Epoch 28/100
# 15/15 [==============================] - 0s 4ms/step - loss: 7.6900e-04 - val_loss: 1.6197e-04
# Epoch 29/100
# 15/15 [==============================] - 0s 5ms/step - loss: 7.1679e-04 - val_loss: 1.5626e-04
# Epoch 30/100
# 15/15 [==============================] - 0s 4ms/step - loss: 6.6389e-04 - val_loss: 1.7036e-04
# Epoch 31/100
# 15/15 [==============================] - 0s 4ms/step - loss: 8.8271e-04 - val_loss: 1.6445e-04
# Epoch 32/100
# 15/15 [==============================] - 0s 5ms/step - loss: 7.4902e-04 - val_loss: 1.4902e-04
# Epoch 33/100
# 15/15 [==============================] - 0s 4ms/step - loss: 6.4878e-04 - val_loss: 1.6073e-04
# Epoch 34/100
# 15/15 [==============================] - 0s 5ms/step - loss: 6.7241e-04 - val_loss: 1.6309e-04
# Epoch 35/100
# 15/15 [==============================] - 0s 4ms/step - loss: 6.2434e-04 - val_loss: 1.6365e-04
# Epoch 36/100
# 15/15 [==============================] - 0s 4ms/step - loss: 6.4122e-04 - val_loss: 1.5575e-04
# Epoch 37/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.6433e-04 - val_loss: 1.7348e-04
# Epoch 38/100
# 15/15 [==============================] - 0s 4ms/step - loss: 7.5746e-04 - val_loss: 1.6195e-04
# Epoch 39/100
# 15/15 [==============================] - 0s 5ms/step - loss: 6.6768e-04 - val_loss: 1.5005e-04
# Epoch 40/100
# 15/15 [==============================] - 0s 4ms/step - loss: 6.6948e-04 - val_loss: 1.6332e-04
# Epoch 41/100
# 15/15 [==============================] - 0s 6ms/step - loss: 7.4352e-04 - val_loss: 1.5950e-04
# Epoch 42/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.9301e-04 - val_loss: 1.4834e-04
# Epoch 43/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.8931e-04 - val_loss: 1.4614e-04
# Epoch 44/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.6199e-04 - val_loss: 1.5094e-04
# Epoch 45/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.8622e-04 - val_loss: 1.5199e-04
# Epoch 46/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.9731e-04 - val_loss: 1.4567e-04
# Epoch 47/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.6982e-04 - val_loss: 1.4837e-04
# Epoch 48/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.4688e-04 - val_loss: 1.6078e-04
# Epoch 49/100
# 15/15 [==============================] - 0s 4ms/step - loss: 8.2958e-04 - val_loss: 1.3778e-04
# Epoch 50/100
# 15/15 [==============================] - 0s 5ms/step - loss: 6.6084e-04 - val_loss: 1.4679e-04
# Epoch 51/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.9769e-04 - val_loss: 1.4573e-04
# Epoch 52/100
# 15/15 [==============================] - 0s 5ms/step - loss: 6.5807e-04 - val_loss: 1.3714e-04
# Epoch 53/100
# 15/15 [==============================] - 0s 7ms/step - loss: 5.5301e-04 - val_loss: 1.4471e-04
# Epoch 54/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.3366e-04 - val_loss: 1.7565e-04
# Epoch 55/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 1.4736e-04
# Epoch 56/100
# 15/15 [==============================] - 0s 5ms/step - loss: 7.9572e-04 - val_loss: 1.4327e-04
# Epoch 57/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.6137e-04 - val_loss: 1.3857e-04
# Epoch 58/100
# 15/15 [==============================] - 0s 7ms/step - loss: 5.9380e-04 - val_loss: 1.4722e-04
# Epoch 59/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.3384e-04 - val_loss: 1.4330e-04
# Epoch 60/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.2398e-04 - val_loss: 1.4270e-04
# Epoch 61/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.3733e-04 - val_loss: 1.3828e-04
# Epoch 62/100
# 15/15 [==============================] - 0s 5ms/step - loss: 6.2174e-04 - val_loss: 1.3914e-04
# Epoch 63/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.1250e-04 - val_loss: 1.4118e-04
# Epoch 64/100
# 15/15 [==============================] - 0s 7ms/step - loss: 5.3691e-04 - val_loss: 1.4532e-04
# Epoch 65/100
# 15/15 [==============================] - 0s 6ms/step - loss: 7.2827e-04 - val_loss: 1.8891e-04
# Epoch 66/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 1.3622e-04
# Epoch 67/100
# 15/15 [==============================] - 0s 6ms/step - loss: 4.9742e-04 - val_loss: 1.4169e-04
# Epoch 68/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.6218e-04 - val_loss: 1.4530e-04
# Epoch 69/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.4272e-04 - val_loss: 1.4121e-04
# Epoch 70/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.1196e-04 - val_loss: 1.6819e-04
# Epoch 71/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 1.5229e-04
# Epoch 72/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.2611e-04 - val_loss: 1.3454e-04
# Epoch 73/100
# 15/15 [==============================] - 0s 4ms/step - loss: 5.4929e-04 - val_loss: 1.4322e-04
# Epoch 74/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.7615e-04 - val_loss: 1.4268e-04
# Epoch 75/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.4318e-04 - val_loss: 1.4678e-04
# Epoch 76/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.2238e-04 - val_loss: 1.5797e-04
# Epoch 77/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.0080e-04 - val_loss: 1.6337e-04
# Epoch 78/100
# 15/15 [==============================] - 0s 6ms/step - loss: 8.3460e-04 - val_loss: 1.3730e-04
# Epoch 79/100
# 15/15 [==============================] - 0s 6ms/step - loss: 4.5734e-04 - val_loss: 1.5555e-04
# Epoch 80/100
# 15/15 [==============================] - 0s 7ms/step - loss: 5.2680e-04 - val_loss: 1.4311e-04
# Epoch 81/100
# 15/15 [==============================] - 0s 6ms/step - loss: 4.4407e-04 - val_loss: 1.4196e-04
# Epoch 82/100
# 15/15 [==============================] - 0s 6ms/step - loss: 4.2907e-04 - val_loss: 1.4291e-04
# Epoch 83/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.5532e-04 - val_loss: 1.3960e-04
# Epoch 84/100
# 15/15 [==============================] - 0s 7ms/step - loss: 4.5897e-04 - val_loss: 1.4113e-04
# Epoch 85/100
# 15/15 [==============================] - 0s 6ms/step - loss: 4.6315e-04 - val_loss: 1.4157e-04
# Epoch 86/100
# 15/15 [==============================] - 0s 7ms/step - loss: 4.4288e-04 - val_loss: 1.3833e-04
# Epoch 87/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.4115e-04 - val_loss: 1.3669e-04
# Epoch 88/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.6291e-04 - val_loss: 1.3587e-04
# Epoch 89/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.2087e-04 - val_loss: 1.4851e-04
# Epoch 90/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.4993e-04 - val_loss: 1.4380e-04
# Epoch 91/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.1685e-04 - val_loss: 1.3537e-04
# Epoch 92/100
# 15/15 [==============================] - 0s 6ms/step - loss: 4.4096e-04 - val_loss: 1.3637e-04
# Epoch 93/100
# 15/15 [==============================] - 0s 6ms/step - loss: 4.4913e-04 - val_loss: 1.4523e-04
# Epoch 94/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.9822e-04 - val_loss: 1.3287e-04
# Epoch 95/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.2549e-04 - val_loss: 1.4022e-04
# Epoch 96/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.7654e-04 - val_loss: 1.4083e-04
# Epoch 97/100
# 15/15 [==============================] - 0s 7ms/step - loss: 6.5253e-04 - val_loss: 1.2932e-04
# Epoch 98/100
# 15/15 [==============================] - 0s 6ms/step - loss: 4.7499e-04 - val_loss: 1.4270e-04
# Epoch 99/100
# 15/15 [==============================] - 0s 5ms/step - loss: 4.5574e-04 - val_loss: 1.3928e-04
# Epoch 100/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.2064e-04 - val_loss: 1.4141e-04

# %%
# 9. Dự báo dữ liệu test
train_predict = model.predict(X_train)
y_pred = model.predict(X_test)
# Out:
# 29/29 [==============================] - 0s 1ms/step
# 5/5 [==============================] - 0s 2ms/step

# %%
# 10. Chuẩn hóa dữ liệu y_pred
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# %%
# 11. Đánh giá độ chính xác thuật toán bằng RMSE và các độ đo khác
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
test_mape = mean_absolute_percentage_error(y_test, y_pred)
test_mae = mean_absolute_error(y_test, y_pred)

print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 17092.446065187087
# Testing MAPE: 216144.48017840882
# Testing MAE: 16907.887235589995

# %%
# 12. Dự báo 30 ngày tiếp theo
x_input = test_data[-100:].reshape(1, -1)
temp_input = x_input[0].tolist()

from numpy import array

lst_output = []
n_steps = 100
i = 0
while i < 30:
    if len(temp_input) > 100:
        x_input = np.array(temp_input[-100:])
        x_input = x_input.reshape((1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = np.array(temp_input).reshape((1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i += 1

# %%
# 13. Vẽ hình
plt.figure(figsize=(14, 8))
dates = pd.to_datetime(df_reversed['Date'])

plt.plot(dates[:train_size], scaler.inverse_transform(train_data), label='Train')
plt.plot(dates[train_size:], scaler.inverse_transform(test_data), label='Test')
predicted_test_index_start = train_size + time_step
plt.plot(dates[predicted_test_index_start:predicted_test_index_start + len(y_pred)], y_pred, label='Predict')
future_dates = pd.date_range(start=dates.iloc[-1], periods=31, inclusive='right')
plt.plot(future_dates, scaler.inverse_transform(lst_output), label='30 Days Prediction')

plt.title('NVL Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Closed Price')
plt.legend()

plt.show()

# %% [markdown]
# ## 3. NLG Dataset

# %%
# 1. Import thư viện cần thiết
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense

# %%
# 2. Đọc file csv và gắn index với giá Close
df = pd.read_csv('../Datasets/3-NLG Historical Data.csv')
df_reversed = df.iloc[::-1].reset_index(drop=True)
df['Date'] = pd.to_datetime(df_reversed['Date'])
df1 = df_reversed['Price']
df1 = df1.str.replace(',', '').astype(float)

# %%
df1
# Out:
# 0       18706.8
# 1       19127.2
# 2       18917.0
# 3       18846.9
# 4       18706.8
#          ...
# 1247    37400.0
# 1248    38500.0
# 1249    38200.0
# 1250    39600.0
# 1251    39900.0
# Name: Price, Length: 1252, dtype: float64

# %%
# 3. Scaler data
scaler=MinMaxScaler(feature_range=(0,1))
df1=scaler.fit_transform(np.array(df1).reshape(-1,1))

# %%
# 4. Chia train test
train_size = int(0.8 * len(df1))
test_size = len(df1) - train_size

train_data = df1[:train_size]
test_data = df1[train_size:]

# %%
# 5. Hàm Create Dataset
import numpy

# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - time_step - 1):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# 6. Reshape into X=t,t+1,t+2..t+99 and Y=t+100
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
# 7. Define MLP Model
model = Sequential()
model.add(Dense(50, input_dim=100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# 8. Fit mô hình với dữ liệu train
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 1s 17ms/step - loss: 0.0282 - val_loss: 0.0016
# Epoch 2/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 3/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0015
# Epoch 4/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0018 - val_loss: 0.0013
# Epoch 5/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 6/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 7/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 8/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 9/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 10/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 11/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 12/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 13/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 14/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 15/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 16/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 17/100
# 15/15 [==============================] - 0s 4ms/step - loss: 9.6796e-04 - val_loss: 0.0012
# Epoch 18/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 19/100
# 15/15 [==============================] - 0s 4ms/step - loss: 9.7911e-04 - val_loss: 0.0010
# Epoch 20/100
# 15/15 [==============================] - 0s 5ms/step - loss: 9.6548e-04 - val_loss: 0.0010
# Epoch 21/100
# 15/15 [==============================] - 0s 5ms/step - loss: 8.7814e-04 - val_loss: 0.0018
# Epoch 22/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 23/100
# 15/15 [==============================] - 0s 5ms/step - loss: 8.4254e-04 - val_loss: 0.0010
# Epoch 24/100
# 15/15 [==============================] - 0s 5ms/step - loss: 8.5887e-04 - val_loss: 0.0011
# Epoch 25/100
# 15/15 [==============================] - 0s 6ms/step - loss: 8.5171e-04 - val_loss: 0.0012
# Epoch 26/100
# 15/15 [==============================] - 0s 5ms/step - loss: 9.0959e-04 - val_loss: 0.0012
# Epoch 27/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 9.6114e-04
# Epoch 28/100
# 15/15 [==============================] - 0s 6ms/step - loss: 9.3586e-04 - val_loss: 0.0014
# Epoch 29/100
# 15/15 [==============================] - 0s 4ms/step - loss: 0.0011 - val_loss: 9.6175e-04
# Epoch 30/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 31/100
# 15/15 [==============================] - 0s 7ms/step - loss: 8.8592e-04 - val_loss: 8.9142e-04
# Epoch 32/100
# 15/15 [==============================] - 0s 5ms/step - loss: 7.5255e-04 - val_loss: 0.0012
# Epoch 33/100
# 15/15 [==============================] - 0s 4ms/step - loss: 9.4401e-04 - val_loss: 0.0029
# Epoch 34/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 35/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 36/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 37/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 0.0017
# Epoch 38/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 39/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 8.1624e-04
# Epoch 40/100
# 15/15 [==============================] - 0s 4ms/step - loss: 8.2929e-04 - val_loss: 0.0013
# Epoch 41/100
# 15/15 [==============================] - 0s 6ms/step - loss: 9.5875e-04 - val_loss: 9.6412e-04
# Epoch 42/100
# 15/15 [==============================] - 0s 4ms/step - loss: 8.1560e-04 - val_loss: 0.0013
# Epoch 43/100
# 15/15 [==============================] - 0s 6ms/step - loss: 9.2522e-04 - val_loss: 9.5790e-04
# Epoch 44/100
# 15/15 [==============================] - 0s 6ms/step - loss: 8.0977e-04 - val_loss: 0.0036
# Epoch 45/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 46/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 8.4736e-04
# Epoch 47/100
# 15/15 [==============================] - 0s 7ms/step - loss: 8.0462e-04 - val_loss: 0.0015
# Epoch 48/100
# 15/15 [==============================] - 0s 11ms/step - loss: 8.5261e-04 - val_loss: 0.0012
# Epoch 49/100
# 15/15 [==============================] - 0s 7ms/step - loss: 8.6664e-04 - val_loss: 8.3430e-04
# Epoch 50/100
# 15/15 [==============================] - 0s 5ms/step - loss: 7.6479e-04 - val_loss: 7.9354e-04
# Epoch 51/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.9054e-04 - val_loss: 9.9477e-04
# Epoch 52/100
# 15/15 [==============================] - 0s 7ms/step - loss: 7.0450e-04 - val_loss: 0.0012
# Epoch 53/100
# 15/15 [==============================] - 0s 6ms/step - loss: 7.4229e-04 - val_loss: 9.1503e-04
# Epoch 54/100
# 15/15 [==============================] - 0s 6ms/step - loss: 7.0680e-04 - val_loss: 8.7837e-04
# Epoch 55/100
# 15/15 [==============================] - 0s 5ms/step - loss: 6.8956e-04 - val_loss: 7.8512e-04
# Epoch 56/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.2245e-04 - val_loss: 8.3073e-04
# Epoch 57/100
# 15/15 [==============================] - 0s 8ms/step - loss: 6.1129e-04 - val_loss: 9.0548e-04
# Epoch 58/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.3228e-04 - val_loss: 0.0012
# Epoch 59/100
# 15/15 [==============================] - 0s 7ms/step - loss: 7.4201e-04 - val_loss: 9.9736e-04
# Epoch 60/100
# 15/15 [==============================] - 0s 6ms/step - loss: 7.2017e-04 - val_loss: 8.1916e-04
# Epoch 61/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.6470e-04 - val_loss: 0.0011
# Epoch 62/100
# 15/15 [==============================] - 0s 5ms/step - loss: 9.2340e-04 - val_loss: 0.0013
# Epoch 63/100
# 15/15 [==============================] - 0s 7ms/step - loss: 7.8207e-04 - val_loss: 8.2735e-04
# Epoch 64/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.4131e-04 - val_loss: 0.0010
# Epoch 65/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.1130e-04 - val_loss: 8.1585e-04
# Epoch 66/100
# 15/15 [==============================] - 0s 5ms/step - loss: 6.2720e-04 - val_loss: 0.0012
# Epoch 67/100
# 15/15 [==============================] - 0s 7ms/step - loss: 9.5810e-04 - val_loss: 8.1673e-04
# Epoch 68/100
# 15/15 [==============================] - 0s 5ms/step - loss: 6.9885e-04 - val_loss: 0.0019
# Epoch 69/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 70/100
# 15/15 [==============================] - 0s 6ms/step - loss: 7.4803e-04 - val_loss: 6.8775e-04
# Epoch 71/100
# 15/15 [==============================] - 0s 7ms/step - loss: 7.0534e-04 - val_loss: 0.0037
# Epoch 72/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 73/100
# 15/15 [==============================] - 0s 7ms/step - loss: 8.2211e-04 - val_loss: 7.4820e-04
# Epoch 74/100
# 15/15 [==============================] - 0s 7ms/step - loss: 8.4239e-04 - val_loss: 7.5075e-04
# Epoch 75/100
# 15/15 [==============================] - 0s 8ms/step - loss: 7.7944e-04 - val_loss: 8.7612e-04
# Epoch 76/100
# 15/15 [==============================] - 0s 9ms/step - loss: 5.9033e-04 - val_loss: 8.4173e-04
# Epoch 77/100
# 15/15 [==============================] - 0s 8ms/step - loss: 6.5463e-04 - val_loss: 0.0011
# Epoch 78/100
# 15/15 [==============================] - 0s 9ms/step - loss: 7.4689e-04 - val_loss: 0.0013
# Epoch 79/100
# 15/15 [==============================] - 0s 6ms/step - loss: 7.8999e-04 - val_loss: 7.7848e-04
# Epoch 80/100
# 15/15 [==============================] - 0s 7ms/step - loss: 5.9061e-04 - val_loss: 7.0896e-04
# Epoch 81/100
# 15/15 [==============================] - 0s 8ms/step - loss: 6.3428e-04 - val_loss: 8.1278e-04
# Epoch 82/100
# 15/15 [==============================] - 0s 5ms/step - loss: 6.1690e-04 - val_loss: 7.0024e-04
# Epoch 83/100
# 15/15 [==============================] - 0s 7ms/step - loss: 5.8386e-04 - val_loss: 7.5161e-04
# Epoch 84/100
# 15/15 [==============================] - 0s 7ms/step - loss: 5.4151e-04 - val_loss: 0.0010
# Epoch 85/100
# 15/15 [==============================] - 0s 8ms/step - loss: 9.7569e-04 - val_loss: 9.5770e-04
# Epoch 86/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.7115e-04 - val_loss: 8.5925e-04
# Epoch 87/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.4793e-04 - val_loss: 0.0010
# Epoch 88/100
# 15/15 [==============================] - 0s 4ms/step - loss: 9.3887e-04 - val_loss: 8.4495e-04
# Epoch 89/100
# 15/15 [==============================] - 0s 5ms/step - loss: 7.5390e-04 - val_loss: 0.0013
# Epoch 90/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.4084e-04 - val_loss: 0.0011
# Epoch 91/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.9981e-04 - val_loss: 0.0013
# Epoch 92/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.3381e-04 - val_loss: 0.0012
# Epoch 93/100
# 15/15 [==============================] - 0s 6ms/step - loss: 6.6303e-04 - val_loss: 7.6486e-04
# Epoch 94/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.2944e-04 - val_loss: 9.5774e-04
# Epoch 95/100
# 15/15 [==============================] - 0s 5ms/step - loss: 7.3666e-04 - val_loss: 7.5269e-04
# Epoch 96/100
# 15/15 [==============================] - 0s 6ms/step - loss: 5.8192e-04 - val_loss: 7.3024e-04
# Epoch 97/100
# 15/15 [==============================] - 0s 5ms/step - loss: 5.0335e-04 - val_loss: 9.7495e-04
# Epoch 98/100
# 15/15 [==============================] - 0s 8ms/step - loss: 6.8768e-04 - val_loss: 9.7861e-04
# Epoch 99/100
# 15/15 [==============================] - 0s 11ms/step - loss: 5.7338e-04 - val_loss: 6.8862e-04
# Epoch 100/100
# 15/15 [==============================] - 0s 9ms/step - loss: 5.4304e-04 - val_loss: 7.4169e-04

# %%
# 9. Dự báo dữ liệu test
train_predict = model.predict(X_train)
y_pred = model.predict(X_test)
# Out:
# 29/29 [==============================] - 0s 5ms/step
# 5/5 [==============================] - 0s 4ms/step

# %%
# 10. Chuẩn hóa dữ liệu y_pred
train_predict = scaler.inverse_transform(train_predict)
y_pred = scaler.inverse_transform(y_pred)

# %%
# 11. Đánh giá độ chính xác thuật toán bằng RMSE và các độ đo khác
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

test_rmse = np.sqrt(np.mean((y_pred - y_test)**2))
test_mape = mean_absolute_percentage_error(y_test, y_pred)
test_mae = mean_absolute_error(y_test, y_pred)

print('Testing RMSE:', test_rmse)
print('Testing MAPE:', test_mape)
print('Testing MAE:', test_mae)
# Out:
# Testing RMSE: 36800.19052704508
# Testing MAPE: 81379.31464656937
# Testing MAE: 36723.337159525116

# %%
# 12. Dự báo 30 ngày tiếp theo
x_input = test_data[-100:].reshape(1, -1)
temp_input = x_input[0].tolist()

from numpy import array

lst_output = []
n_steps = 100
i = 0
while i < 30:
    if len(temp_input) > 100:
        x_input = np.array(temp_input[-100:])
        x_input = x_input.reshape((1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]
        lst_output.extend(yhat.tolist())
        i += 1
    else:
        x_input = np.array(temp_input).reshape((1, n_steps))
        yhat = model.predict(x_input, verbose=0)
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        i += 1

# %%
# 13. Vẽ hình
plt.figure(figsize=(14, 8))
dates = pd.to_datetime(df_reversed['Date'])

plt.plot(dates[:train_size], scaler.inverse_transform(train_data), label='Train')
plt.plot(dates[train_size:], scaler.inverse_transform(test_data), label='Test')
predicted_test_index_start = train_size + time_step
plt.plot(dates[predicted_test_index_start:predicted_test_index_start + len(y_pred)], y_pred, label='Predict')
future_dates = pd.date_range(start=dates.iloc[-1], periods=31, inclusive='right')
plt.plot(future_dates, scaler.inverse_transform(lst_output), label='30 Days Prediction')

plt.title('NLG Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Closed Price')
plt.legend()

plt.show()
